# %%
#%%
import numpy as np
import pandas as pd
import pickle
import os.path
import random
import category_encoders as ce

from sklearn import preprocessing
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %%
db_genba = pd.read_csv("train_genba.tsv",encoding="utf8",sep="\t")
db_goto = pd.read_csv("train_goto.tsv",encoding="utf8",sep="\t")

#%%
db = pd.merge(db_genba, db_goto, on='pj_no', how='left')

#%%
Y = db["keiyaku_pr"]
X = db.drop("keiyaku_pr",axis=1)



X = X.fillna(0)
Y = Y.fillna(0)

#%%

#タイプがobject(文字列)の列list
list_cols = X.columns[X.dtypes == "object"]
list_cols = list(list_cols)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-383-c1751f300e19> in <module>
#      19 #タイプがobject(文字列)の列list
#      20 list_cols = X.columns[X.dtypes == "object"]
# ---> 21 list_cols = list(list_cols)
#
# TypeError: 'list' object is not callable

# %%
X[list_cols[31:41:]]
# Out:
#      hokakisei3 hokakisei4 kinshijiko fi4m_yohi fi3m_yohi bus_yohi sho_conv  \
# 0             0          0        （無）      （不要）      （不要）     （不要）        0
# 1             0          0        （無）      （不要）      （不要）     （不要）        0
# 2             0          0        （無）      （不要）      （不要）      （要）        ○
# 3             0          0        （無）      （不要）      （不要）     （不要）        0
# 4         埋蔵文化財          0        （無）      （不要）      （不要）     （不要）        ○
# 5         埋蔵文化財          0        （無）      （不要）      （不要）     （不要）        ○
# 6         埋蔵文化財          0        （無）      （不要）      （不要）     （不要）        ○
# 7             0          0        （無）      （不要）      （不要）      （要）        0
# 8             0          0        （無）      （不要）      （不要）     （不要）        0
# 9             0          0        （無）      （不要）      （不要）     （不要）        0
# 10            0          0        （無）      （不要）      （不要）     （不要）        ○
# 11            0          0        （無）      （不要）      （不要）     （不要）        ○
# 12            0          0        （無）      （不要）      （不要）      （要）        ○
# 13            0          0        （無）      （不要）      （不要）      （要）        ○
# 14            0          0        （無）      （不要）      （不要）     （不要）        ○
# 15            0          0        （無）      （不要）      （不要）     （不要）        ○
# 16            0          0        （無）      （不要）      （不要）     （不要）        ○
# 17            0          0        （無）      （不要）      （不要）     （不要）        0
# 18            0          0        （無）      （不要）      （不要）     （不要）        ○
# 19            0          0        （無）      （不要）      （不要）     （不要）        ○
# 20            0          0        （無）      （不要）      （不要）      （要）        ○
# 21            0          0        （無）      （不要）      （不要）      （要）        ○
# 22            0          0        （無）      （不要）      （不要）     （不要）        0
# 23            0          0        （無）      （不要）      （不要）     （不要）        0
# 24            0          0        （無）      （不要）      （不要）     （不要）        ○
# 25            0          0        （無）      （不要）      （不要）     （不要）        0
# 26            0          0        （無）      （不要）      （不要）      （要）        ○
# 27            0          0        （無）      （不要）      （不要）     （不要）        ○
# 28            0          0        （無）      （不要）      （不要）     （不要）        ○
# 29            0          0        （無）      （不要）      （不要）      （要）        0
# ...         ...        ...        ...       ...       ...      ...      ...
# 6431          0          0        （無）      （不要）      （不要）     （不要）        0
# 6432          0          0        （無）      （不要）      （不要）     （不要）        0
# 6433          0          0        （無）      （不要）      （不要）     （不要）        0
# 6434          0          0        （無）      （不要）      （不要）     （不要）        0
# 6435          0          0        （無）      （不要）      （不要）     （不要）        0
# 6436          0          0        （無）      （不要）      （不要）     （不要）        ○
# 6437          0          0        （無）      （不要）      （不要）     （不要）        ○
# 6438          0          0        （無）      （不要）      （不要）     （不要）        ○
# 6439          0          0        （無）      （不要）      （不要）     （不要）        ○
# 6440          0          0        （無）      （不要）      （不要）     （不要）        ○
# 6441          0          0        （無）      （不要）      （不要）     （不要）        ○
# 6442          0          0        （無）      （不要）      （不要）     （不要）        ○
# 6443          0          0        （無）      （不要）      （不要）     （不要）        ○
# 6444          0          0        （無）      （不要）      （不要）      （要）        ○
# 6445          0          0        （無）      （不要）      （不要）     （不要）        0
# 6446          0          0        （無）      （不要）      （不要）     （不要）        0
# 6447          0          0        （無）      （不要）      （不要）     （不要）        0
# 6448          0          0        （無）      （不要）      （不要）     （不要）        0
# 6449          0          0        （無）      （不要）      （不要）     （不要）        0
# 6450          0          0        （無）      （不要）      （不要）     （不要）        0
# 6451          0          0        （無）      （不要）      （不要）     （不要）        ○
# 6452          0          0        （無）      （不要）      （不要）     （不要）        ○
# 6453          0          0        （無）      （不要）      （不要）     （不要）        ○
# 6454          0          0        （無）      （不要）      （不要）     （不要）        ○
# 6455          0          0        （無）      （不要）      （不要）     （不要）        ○
# 6456          0          0        （無）      （不要）      （不要）      （要）        ○
# 6457          0          0        （無）      （不要）      （不要）      （要）        ○
# 6458          0          0        （無）      （不要）      （不要）      （要）        ○
# 6459          0          0        （無）      （不要）      （不要）      （要）        ○
# 6460          0          0        （無）      （不要）      （不要）      （要）        ○
#
#      sho_super sho_shoten sho_market
# 0            0          0          0
# 1            0          0          0
# 2            0          0          0
# 3            0          0          0
# 4            0          0          0
# 5            0          0          0
# 6            0          0          0
# 7            0          0          0
# 8            0          0          0
# 9            0          0          0
# 10           0          0          0
# 11           0          0          0
# 12           ○          0          0
# 13           ○          0          0
# 14           0          0          0
# 15           0          0          0
# 16           0          0          0
# 17           0          0          0
# 18           0          0          0
# 19           0          0          0
# 20           ○          0          0
# 21           ○          0          0
# 22           0          0          0
# 23           0          0          0
# 24           ○          0          0
# 25           0          0          0
# 26           0          0          0
# 27           0          0          0
# 28           0          0          0
# 29           ○          0          0
# ...        ...        ...        ...
# 6431         0          0          0
# 6432         0          0          0
# 6433         0          0          0
# 6434         0          0          0
# 6435         0          0          0
# 6436         0          0          0
# 6437         0          0          0
# 6438         0          0          0
# 6439         ○          0          0
# 6440         ○          0          0
# 6441         ○          0          0
# 6442         ○          0          0
# 6443         0          0          0
# 6444         0          0          0
# 6445         0          0          0
# 6446         0          0          0
# 6447         0          0          0
# 6448         0          0          0
# 6449         0          0          0
# 6450         0          0          0
# 6451         ○          0          ○
# 6452         ○          0          ○
# 6453         ○          0          ○
# 6454         ○          0          ○
# 6455         ○          0          ○
# 6456         ○          ○          0
# 6457         ○          ○          0
# 6458         ○          ○          0
# 6459         ○          ○          0
# 6460         ○          ○          0
#
# [6461 rows x 10 columns]

# %%
X['jukyo'].str.split('[市郡]',expand=True)
# Out:
#             0          1     2
# 0       埼玉県朝霞         泉水  None
# 1       埼玉県川越       大字的場  None
# 2       埼玉県川口        安行原  None
# 3       埼玉県草加         松江  None
# 16     埼玉県北葛飾    杉戸町大字堤根
# 17      埼玉県所沢        中新井
# 18      埼玉県川口        西川口
# 19      埼玉県加須         花崎
# 20      埼玉県所沢        中富南
# 21      埼玉県所沢        中富南
# 22      埼玉県熊谷         石原
# 23      埼玉県熊谷         石原
# 24    埼玉県ふじみ野        上福岡
# 25     埼玉県鶴ヶ島     大字太田ヶ谷
# 26      埼玉県草加        八幡町
# 27      埼玉県新座         西堀
# 28      埼玉県新座         西堀
# 29     埼玉県春日部       新宿新田
# ...       ...        ...
# 6431    埼玉県川口         安行
# 6432    埼玉県川口         安行
# 6433    埼玉県川口         安行
# 6434    埼玉県川口         安行
# 6435    埼玉県川口         安行
# 6436   埼玉県鶴ヶ島      大字下新田
# 6437   埼玉県鶴ヶ島      大字下新田
# 6438   埼玉県鶴ヶ島      大字下新田
# 6439    埼玉県川口        戸塚東
# 6440    埼玉県川口        戸塚東
# 6441    埼玉県川口        戸塚東
# 6442    埼玉県川口        戸塚東
# 6443    埼玉県草加         西町
# 6444    埼玉県越谷     大字下間久里
# 6445  埼玉県さいたま      岩槻区加倉
# 6446  埼玉県さいたま      岩槻区加倉
# 6447  埼玉県さいたま      岩槻区加倉
# 6448    埼玉県久喜       栗橋中央
# 6449    埼玉県久喜       栗橋中央
# 6450    埼玉県久喜       栗橋中央
# 6451    埼玉県鴻巣        北新宿
# 6452    埼玉県鴻巣        北新宿
# 6453    埼玉県鴻巣        北新宿
# 6454    埼玉県鴻巣        北新宿
# 6455    埼玉県鴻巣        北新宿
# 6456    埼玉県川口         領家
# 6457    埼玉県川口         領家
# 6458    埼玉県川口         領家
# 6459    埼玉県川口         領家
# 6460    埼玉県川口         領家
#
# [6461 rows x 2 columns]

# %%
X['jukyo']
# Out:
# 0               埼玉県朝霞市泉水
# 1             埼玉県川越市大字的場
# 2              埼玉県川口市安行原
# 3               埼玉県草加市松江
# 4              埼玉県新座市野火止
# 5              埼玉県新座市野火止
# 6              埼玉県新座市野火止
# 7        埼玉県桶川市大字上日出谷字殿山
# 8       埼玉県さいたま市見沼区片柳字南台
# 9       埼玉県さいたま市見沼区片柳字南台
# 10              埼玉県上尾市東町
# 11              埼玉県上尾市東町
# 12              埼玉県狭山市中央
# 13              埼玉県狭山市中央
# 14        埼玉県北葛飾郡杉戸町大字堤根
# 15        埼玉県北葛飾郡杉戸町大字堤根
# 16        埼玉県北葛飾郡杉戸町大字堤根
# 17             埼玉県所沢市中新井
# 18             埼玉県川口市西川口
# 19              埼玉県加須市花崎
# 20             埼玉県所沢市中富南
# 21             埼玉県所沢市中富南
# 22              埼玉県熊谷市石原
# 23              埼玉県熊谷市石原
# 24           埼玉県ふじみ野市上福岡
# 25         埼玉県鶴ヶ島市大字太田ヶ谷
# 26             埼玉県草加市八幡町
# 27              埼玉県新座市西堀
# 28              埼玉県新座市西堀
# 29           埼玉県春日部市新宿新田
#               ...
# 6431            埼玉県川口市安行
# 6432            埼玉県川口市安行
# 6433            埼玉県川口市安行
# 6434            埼玉県川口市安行
# 6435            埼玉県川口市安行
# 6436        埼玉県鶴ヶ島市大字下新田
# 6437        埼玉県鶴ヶ島市大字下新田
# 6438        埼玉県鶴ヶ島市大字下新田
# 6439           埼玉県川口市戸塚東
# 6440           埼玉県川口市戸塚東
# 6441           埼玉県川口市戸塚東
# 6442           埼玉県川口市戸塚東
# 6443            埼玉県草加市西町
# 6444        埼玉県越谷市大字下間久里
# 6445       埼玉県さいたま市岩槻区加倉
# 6446       埼玉県さいたま市岩槻区加倉
# 6447       埼玉県さいたま市岩槻区加倉
# 6448          埼玉県久喜市栗橋中央
# 6449          埼玉県久喜市栗橋中央
# 6450          埼玉県久喜市栗橋中央
# 6451           埼玉県鴻巣市北新宿
# 6452           埼玉県鴻巣市北新宿
# 6453           埼玉県鴻巣市北新宿
# 6454           埼玉県鴻巣市北新宿
# 6455           埼玉県鴻巣市北新宿
# 6456            埼玉県川口市領家
# 6457            埼玉県川口市領家
# 6458            埼玉県川口市領家
# 6459            埼玉県川口市領家
# 6460            埼玉県川口市領家
# Name: jukyo, Length: 6461, dtype: object

# %%
te = ce.TargetEncoder(cols=list_cols, handle_unknown='ignore')
X = te.fit_transform(X, Y)
ETF_df = X

# %%
train_te
# Out:
#       pj_no         jukyo  chiseki_js_hb  chiseki_kb_hb         yoto1  \
# 0         0  2.782169e+07         109.26         109.10  2.793594e+07
# 1         1  2.641111e+07         136.15         136.00  2.716880e+07
# 2         2  2.680923e+07          86.92          86.52  2.716880e+07
# 3         3  3.182300e+07         164.91         164.07  2.793594e+07
# 4         4  3.614995e+07         403.58         403.58  2.716880e+07
# 5         4  3.614995e+07         403.58         403.58  2.716880e+07
# 6         4  3.614995e+07         403.58         403.58  2.716880e+07
# 7         5  2.594028e+07         114.44         114.55  2.794198e+07
# 8         6  2.104354e+07         531.98         498.06  2.367853e+07
# 9         6  2.104354e+07         531.98         498.06  2.367853e+07
# 10        7  2.444296e+07         242.78         242.78  2.794198e+07
# 11        7  2.444296e+07         242.78         242.78  2.794198e+07
# 12        8  2.334055e+07         224.99         224.99  2.897954e+07
# 13        8  2.334055e+07         224.99         224.99  2.897954e+07
# 14        9  2.410339e+07        1010.00        1002.00  2.367853e+07
# 15        9  2.410339e+07        1010.00        1002.00  2.367853e+07
# 16        9  2.410339e+07        1010.00        1002.00  2.367853e+07
# 17       10  2.580909e+07         166.37         166.00  2.716880e+07
# 18       11  3.738270e+07          84.62          84.62  3.013069e+07
# 19       12  2.782169e+07         212.61         212.61  2.716880e+07
# 20       13  2.884998e+07         289.90         289.89  2.897954e+07
# 21       13  2.884998e+07         289.90         289.89  2.897954e+07
# 22       14  2.462222e+07         312.06         312.06  2.794198e+07
# 23       14  2.462222e+07         312.06         312.06  2.794198e+07
# 24       15  2.922382e+07          73.26          85.00  2.794198e+07
# 25       16  2.782169e+07         300.84         300.84  2.367853e+07
# 26       17  2.868338e+07          99.93         100.00  2.794198e+07
# 27       18  2.822667e+07         261.62         261.63  2.716880e+07
# 28       18  2.822667e+07         261.62         261.63  2.716880e+07
# 29       19  2.304476e+07         165.28         165.28  2.716880e+07
# ...     ...           ...            ...            ...           ...
# 6431   2772  3.283165e+07        1555.22        1372.30  2.367853e+07
# 28    2.800799e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 29    2.800799e+07  2.775670e+07  2.784818e+07  2.782366e+07
# ...            ...           ...           ...           ...
# 6431  2.763077e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6432  2.983333e+07  2.909628e+07  2.750526e+07  2.782366e+07
# 6433  2.800799e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6434  2.983333e+07  2.705960e+07  2.784818e+07  2.782366e+07
# 6435  2.983333e+07  2.839860e+07  2.784818e+07  2.782366e+07
# 6436  2.362506e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6437  2.362506e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6438  2.362506e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6439  2.800799e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6440  2.800799e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6441  2.800799e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6442  2.800799e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6443  2.820128e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6444  2.805016e+07  2.753636e+07  3.013810e+07  2.782366e+07
# 6445  2.856673e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6446  2.856673e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6447  2.856673e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6448  2.745102e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6449  2.745102e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6450  2.745102e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6451  2.745102e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6452  2.745102e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6453  2.745102e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6454  2.763077e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6455  2.745102e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6456  2.800799e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6457  2.800799e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6458  2.800799e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6459  2.800799e+07  2.775670e+07  2.784818e+07  2.782366e+07
# 6460  2.800799e+07  2.775670e+07  2.784818e+07  2.782366e+07
#
# [6461 rows x 157 columns]

# %%
test_te = te.transform(test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-286-b370db268cd1> in <module>
# ----> 1 test_te = te.transform(test)
#
# NameError: name 'test' is not defined

# %%
#%%

# OneHotEncodeしたい列を指定。Nullや不明の場合の補完方法も指定。
ce_oe = ce.OrdinalEncoder(cols=list_cols,handle_unknown='impute')
X = ce_oe.fit_transform(X)

ETF_df = X

#%%

# %%
variable_num = 50

if os.path.exists("max_accuracy1.sav"):
    max_accuracy1 = pickle.load(open("max_accuracy1.sav","rb"))
else:
    max_accuracy1 = 100

if os.path.exists("max_accuracy2.sav"):
    max_accuracy2 = pickle.load(open("max_accuracy2.sav","rb"))
else:
    max_accuracy2 = 100

if os.path.exists("max_accuracy3.sav"):
    max_accuracy3 = pickle.load(open("max_accuracy3.sav","rb"))
else:
    max_accuracy3 = 100



print(max_accuracy1)
print(max_accuracy2)
print(max_accuracy3)

def cal_mape(A,B):
    return(np.sum(np.abs((A-B)/B))*(100/len(A)))
# Out:
# 7.878775921439605
# 7.998580805495658
# 8.056664264059577

# %%
for n in range(1,11):
    print(str(n) + "回目")
    
    N_train = int(len(X.index) * 0.8)
    N_test = len(X.index) - N_train
    
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=N_test,shuffle = True)
    
    tuned_parameters = [{'n_estimators':[100,200]}]
    clf = GridSearchCV(
        RandomForestRegressor(),
        tuned_parameters,
        cv=4,
        scoring='neg_median_absolute_error'
    )
    
    clf.fit(X_train,list(Y_train))
    
    clf = clf.best_estimator_
    print(clf.n_estimators)
    
    
    #予想
    pred = clf.predict(X_test)
    
    #精度算出
    accuracy = cal_mape(pred,Y_test.values)
    
    
    #最高精度の情報を保存
    if accuracy < max_accuracy1:
        print("★精度更新★1")
        
        max_accuracy3 = max_accuracy2
        max_accuracy2 = max_accuracy1
        max_accuracy1 = accuracy
        
        if os.path.exists("max_accuracy1.sav"):
            
            if os.path.exists("max_accuracy2.sav"):
                #2番目を3番目に移動
                pickle.dump(pickle.load(open("max_accuracy2.sav","rb")),open("max_accuracy3.sav","wb"))
                pickle.dump(pickle.load(open("max_clf2.sav","rb")),open("max_clf3.sav","wb"))
                pickle.dump(pickle.load(open("max_X2.sav","rb")),open("max_X3.sav","wb"))
                
            #1番目を2番目に移動
            pickle.dump(pickle.load(open("max_accuracy1.sav","rb")),open("max_accuracy2.sav","wb"))
            pickle.dump(pickle.load(open("max_clf1.sav","rb")),open("max_clf2.sav","wb"))
            pickle.dump(pickle.load(open("max_X1.sav","rb")),open("max_X2.sav","wb"))
        
        #1番モデル保存
        pickle.dump(accuracy,open("max_accuracy1.sav","wb"))
        pickle.dump(clf,open("max_clf1.sav","wb"))
        pickle.dump(X,open("max_X1.sav","wb"))
    
    elif accuracy < max_accuracy2:
        print("★精度更新★2")
        
        max_accuracy3 = max_accuracy2
        max_accuracy2 = accuracy
        
        if os.path.exists("max_accuracy2.sav"):
            #2番目を3番目に移動
            pickle.dump(pickle.load(open("max_accuracy2.sav","rb")),open("max_accuracy3.sav","wb"))
            pickle.dump(pickle.load(open("max_clf2.sav","rb")),open("max_clf3.sav","wb"))
            pickle.dump(pickle.load(open("max_X2.sav","rb")),open("max_X3.sav","wb"))
        
        #2番モデル保存
        pickle.dump(accuracy,open("max_accuracy2.sav","wb"))
        pickle.dump(clf,open("max_clf2.sav","wb"))
        pickle.dump(X,open("max_X2.sav","wb"))
    
    elif accuracy < max_accuracy3:
        print("★精度更新★3")
        
        max_accuracy3 = accuracy
        
        #モデル保存
        pickle.dump(accuracy,open("max_accuracy3.sav","wb"))
        pickle.dump(clf,open("max_clf3.sav","wb"))
        pickle.dump(X,open("max_X3.sav","wb"))
    
    print(accuracy)
    
    #特徴量ランキングの作成
    features = X.columns
    importances = clf.feature_importances_
    indices = np.argsort(importances)
    
    if 0 in importances:
        #特徴量が0の説明変数が存在する場合、0のものはすべて削除
        X = X.drop(columns=X.columns[importances == 0],axis=1) 
        print("説明変数削除")
    else:
        #それ以外の場合、特徴量の小さい順に説明変数を削除して説明変数の数をvariable_num以下にする
        count = 0
        while len(X.columns) + 5  > variable_num:
            X = X.drop(features[indices][count],axis=1)
            count += 1
            
        #ランダムに説明変数を1つ追加する
        while len(X.columns) <= variable_num:
            temp = random.randrange(len(ETF_df.columns))
            add_column = ETF_df.columns[temp]
            
            #既存のものとかぶらないように追加
            if add_column not in list(X.columns):
                X[add_column] = ETF_df[add_column]
        print("説明変数更新")
            
    X = X.fillna(0)
    print("-------------------------")
# Out:
# 1回目
# 100
# ★精度更新★1
# 7.672600976138724
# 説明変数削除
# -------------------------
# 2回目
# 100
# 8.230987205608894
# 説明変数更新
# -------------------------
# 3回目
# 100
# 8.414034804655934
# 説明変数更新
# -------------------------
# 4回目
# 100
# 9.633642518389932
# 説明変数更新
# -------------------------
# 5回目
# 100
# ★精度更新★3
# 7.9029808723707555
# 説明変数更新
# -------------------------
# 6回目
# 100
# 8.231834882882136
# 説明変数更新
# -------------------------
# 7回目
# 100
# 8.765852163606784
# 説明変数更新
# -------------------------
# 8回目
# 100
# 8.065778739120825
# 説明変数更新
# -------------------------
# 9回目
# 100
# ★精度更新★2
# 7.809898094634943
# 説明変数更新
# -------------------------
# 10回目
# 100
# ★精度更新★1
# 7.513478224456491
# 説明変数更新
# -------------------------

# %%
#特徴量確認
import matplotlib.pyplot as plt
# %matplotlib inline

Xcolumns = X_train.columns
features = Xcolumns
importances = clf.feature_importances_
indices = np.argsort(importances)

plt.figure(figsize=(6,40))
plt.barh(range(len(indices)),importances[indices],color="b",align="center")
plt.yticks(range(len(indices)),features[indices])
plt.show()

# %%
X = pickle.load(open("max_X1.sav","rb"))

# %%
X
# Out:
#       rosenka_hb  koji_hb  kijun_hb  tc_mseki_min_hb  tt_mseki_min_hb  \
# 0         135000   188000    197000           109.26           104.43
# 1          68000    84900     48600           136.15           109.10
# 2          83000   116000    124000            86.92            85.96
# 3          91000   122000    113000           164.07           105.99
# 4         160000   179000    160000           111.52            89.27
# 5         160000   179000    160000           111.52            89.27
# 6         160000   179000    160000           111.52            89.27
# 7              0    83100     85300           114.00            98.95
# 8              0    42600     99000           241.73             0.00
# 9              0    42600     99000           241.73             0.00
# 10         68000   105000     96500           109.44            94.77
# 11         68000   105000     96500           109.44            94.77
# 12         96000   119000    139000           112.48            91.00
# 13         96000   119000    139000           112.48            91.00
# 14             0    15500     59100           300.00           105.99
# 15             0    15500     59100           300.00           105.99
# 16             0    15500     59100           300.00           105.99
# 17        115000   146000    172000           167.02           110.96
# 18        205000   258000    344000            84.62            92.00
# 19         36000    42500     43000           212.61            97.00
# 20         89000   114000    115000           128.60           103.00
# 21         89000   114000    115000           128.60           103.00
# 22         32800    54000     63800           150.46           101.00
# 23         32800    54000     63800           150.46           101.00
# 24        140000   174000    182000            73.26           105.16
# 25         74000    91200    104000           300.84           112.99
# 26         84000    99000    129000           100.42           101.02
# 27        125000   195000    162000           130.81           105.99
# 28        125000   195000    162000           130.81           105.99
# 6443       0.0          1           1          1       0.0          1
# 6444       0.0          1           1          1       0.0          1
# 6445       0.0          1           1          1       0.0          1
# 6446       0.0          1           1          1       0.0          1
# 6447       0.0          1           1          1       0.0          1
# 6448       0.0          1           1          1       0.0          1
# 6449       0.0          1           1          1       0.0          1
# 6450       0.0          1           1          1       0.0          1
# 6451       0.0          1           1          1       0.0          1
# 6452       0.0          1           1          1       0.0          1
# 6453       0.0          1           1          1       0.0          1
# 6454       0.0          1           1          1       0.0          1
# 6455       0.0          1           1          1       0.0          1
# 6456       0.0          1           1          1       0.0          1
# 6457       0.0          1           1          1       0.0          1
# 6458       0.0          1           1          1       0.0          1
# 6459       0.0          1           1          1       0.0          1
# 6460       0.0          1           1          1       0.0          1
#
#       hy1f_date_su  shu_sogi  shu_line_nashi
# 0              0.0         1               1
# 1              0.0         1               1
# 2              0.0         1               1
# 3              0.0         1               1
# 4              0.0         1               1
# 5              0.0         1               1
# 6              0.0         1               1
# 7              0.0         1               1
# 8              0.0         1               1
# 9              0.0         1               1
# 10             0.0         1               1
# 11             0.0         1               1
# 12             0.0         1               1
# 13             0.0         1               1
# 14             0.0         1               1
# 15             0.0         1               1
# 16             0.0         1               1
# 17             0.0         1               1
# 18             0.0         1               1
# 19             0.0         1               1
# 20             0.0         1               1
# 21             0.0         1               1
# 22             0.0         1               1
# 23             0.0         1               1
# 24             0.0         1               1
# 25             0.0         1               1
# 26             0.0         1               1
# 27             0.0         1               1
# 28             0.0         1               1
# 29             0.0         1               1
# ...            ...       ...             ...
# 6431           0.0         1               1
# 6432           0.0         1               1
# 6433           0.0         1               1
# 6434           0.0         1               1
# 6435           0.0         1               1
# 6436           0.0         1               1
# 6437           0.0         1               1
# 6438           0.0         1               1
# 6439           0.0         1               1
# 6440           0.0         1               1
# 6441           0.0         1               1
# 6442           0.0         1               1
# 6443           0.0         1               1
# 6444           0.0         1               1
# 6445           0.0         1               1
# 6446           0.0         1               1
# 6447           0.0         1               1
# 6448           0.0         1               1
# 6449           0.0         1               1
# 6450           0.0         1               1
# 6451           0.0         1               1
# 6452           0.0         1               1
# 6453           0.0         1               1
# 6454           0.0         1               1
# 6455           0.0         1               1
# 6456           0.0         1               1
# 6457           0.0         1               1
# 6458           0.0         1               1
# 6459           0.0         1               1
# 6460           0.0         1               1
#
# [6461 rows x 151 columns]

# %%
tuned_parameters = [{'n_estimators':[50,100,200,300]}]
clf = GridSearchCV(
    RandomForestRegressor(),
    tuned_parameters,
    cv=4,
    scoring='neg_median_absolute_error',
    n_jobs=-1
)

clf.fit(X,list(Y))
# Out:
# GridSearchCV(cv=4, error_score='raise-deprecating',
#              estimator=RandomForestRegressor(bootstrap=True, criterion='mse',
#                                              max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators='warn', n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
#              iid='warn', n_jobs=-1,
#              param_grid=[{'n_estimators': [50, 100, 200, 300]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='neg_median_absolute_error', verbose=0)

# %%
#clfから予想
clf = pickle.load(open("max_clf1.sav","rb"))
X = pickle.load(open("max_X1.sav","rb"))

db_genba_t = pd.read_csv("test_genba.tsv",encoding="utf8",sep="\t")
db_goto_t = pd.read_csv("test_goto.tsv",encoding="utf8",sep="\t")
merge_t = pd.merge(db_genba_t, db_goto_t, on='pj_no', how='left')

merge_t = te.transform(merge_t)

merge_t = merge_t.fillna(0)

merge_t = merge_t[X.columns]

pred_t = clf.predict(merge_t)
pred_t = np.round(pred_t)
print(pred_t)
# Out:
# [20728700. 25583856. 25684000. ... 17967317. 17928750. 26905140.]

# %%
db_genba_t = pd.read_csv("test_genba.tsv",encoding="utf8",sep="\t")
db_goto_t = pd.read_csv("test_goto.tsv",encoding="utf8",sep="\t")

#%%
X_t = pd.merge(db_genba_t, db_goto_t, on='pj_no', how='left')

X_t = ce_oe.fit_transform(X_t)
X_t = X_t.fillna(0)

# %%
X_t = X_t[X.columns]

# %%
pred_t = clf.predict(X_t)
pred_t = np.round(pred_t)
print(pred_t)
# Out:
# [20933333. 26539171. 27039211. ... 29985133. 29929466. 26015233.]

# %%
pred_t = pred_t.astype(np.int64)
print(pred_t)
# Out:
# [20728700 25583856 25684000 ... 17967317 17928750 26905140]

# %%
db_sample = pd.read_csv("sample_submit.tsv",encoding="utf8",sep="\t", names=('name', 'keiyaku_pr'))

# %%
db_sample["keiyaku_pr"] = pred_t

# %%
db_sample
# Out:
#            name  keiyaku_pr
# 0     test_0000    20728700
# 1     test_0001    25583856
# 2     test_0002    25684000
# 3     test_0003    26275900
# 4     test_0004    26080556
# 5     test_0005    25290000
# 6     test_0006    26316778
# 7     test_0007    25481778
# 8     test_0008    25684378
# 9     test_0009    27887356
# 10    test_0010    26366056
# 11    test_0011    31832326
# 12    test_0012    36503911
# 13    test_0013    36231786
# 14    test_0014    27905668
# 15    test_0015    26701024
# 16    test_0016    19907900
# 17    test_0017    20672900
# 18    test_0018    19927000
# 19    test_0019    20610800
# 20    test_0020    20624900
# 21    test_0021    20229000
# 22    test_0022    20247900
# 23    test_0023    19899900
# 24    test_0024    20195900
# 25    test_0025    20229000
# 26    test_0026    19950900
# 27    test_0027    20082700
# 28    test_0028    20128900
# 29    test_0029    20030800
# ...         ...         ...
# 4243  test_4243    38274693
# 4244  test_4244    38646730
# 4245  test_4245    22563533
# 4246  test_4246    31493700
# 4247  test_4247    17241817
# 4248  test_4248    17160817
# 4249  test_4249    16642233
# 4250  test_4250    16793233
# 4251  test_4251    28390725
# 4252  test_4252    29461708
# 4253  test_4253    34293012
# 4254  test_4254    31417573
# 4255  test_4255    30823273
# 4256  test_4256    23537961
# 4257  test_4257    22958261
# 4258  test_4258    18367640
# 4259  test_4259    18728000
# 4260  test_4260    17891040
# 4261  test_4261    18468900
# 4262  test_4262    18266900
# 4263  test_4263    18140500
# 4264  test_4264    16576500
# 4265  test_4265    31746840
# 4266  test_4266    31783840
# 4267  test_4267    21639600
# 4268  test_4268    21596800
# 4269  test_4269    23047704
# 4270  test_4270    17967317
# 4271  test_4271    17928750
# 4272  test_4272    26905140
#
# [4273 rows x 2 columns]

# %%
db_sample.to_csv('sample_submit.tsv',header=False,index=False,sep="\t",line_terminator='\n')
